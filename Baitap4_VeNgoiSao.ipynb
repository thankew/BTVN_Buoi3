# %%
import turtle as t
t.pensize(3)
t.pencolor("red")

side = 100
hs = side / 2
turn = 72

t.left(90)
t.forward(hs)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(hs)

t.left(turn)

t.forward(hs)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(hs)

t.left(turn)

t.forward(hs)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(hs)

t.left(turn)

t.forward(hs)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(hs)

t.left(turn)

t.forward(hs)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(side)
t.right(90)
t.forward(hs)
t.done()
